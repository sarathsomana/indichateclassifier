# %%
import pandas as pd

train_data = pd.read_csv("l3cube_mr_train.csv")
val_data = pd.read_csv("l3cube_mr_val.csv")
test_data = pd.read_csv("l3cube_mr_test.csv")

train_data.head(), val_data.head(), test_data.head()
# Out:
# (                 uid  \
#  0  l3cube_mr_train_0
#  1  l3cube_mr_train_1
#  2  l3cube_mr_train_2
#  3  l3cube_mr_train_3
#  4  l3cube_mr_train_4
#
#                                                                                        text  \
#  0                                                 @Rohitkh76543 @PawarSpeaks तू कोण लवड्या
#  1                                        @mohitbharatiya_ लवड्या अगोदरच रडायला लागलास तू 😂
#  2                           कुठं तरी आईघाल जा लवड्या, काही केला तरी तुझी काई खाज भगत नाही.
#  3  तेलतुंबड्या सारख्या च्या नाजायज पैदाइशीचा कुत्रकार... हिंदुत्वाचा तिरस्कार करनारच ना...
#  4     @TV9Marathi @BJP4Maharashtra नेता...???मादरचोद ची शहरप्रमुख व्हायची लायकी आहे का...😒
#
#     label_yn
#  0         1
#  1         1
#  2         1
#  3         1
#  4         1  ,
#                 uid  \
#  0  l3cube_mr_val_0
#  1  l3cube_mr_val_1
#  2  l3cube_mr_val_2
#  3  l3cube_mr_val_3
#  4  l3cube_mr_val_4
#
#                                                                                                                                                                                                                                                                                                 text  \
#  0                                                                                                                                                                                                                          @BhatkhalkarA तुझी लायकी काय तू बोलतो कोणा बदल काय लाज लज्जा आहे की नाही
#  1                                                                                                                                हिंदू धर्माबद्दल अपशब्द उगारणारा मोकाट आन उस्मानी मामू ला त्याची औकात दाखवणाऱ्या ला अटक.. अजब सरकार #ArrestUddhavThackrey #MahaVikasAghadi https://t.co/Yk1wUtWXIF
#  2          @abpmajhatv खांडक्या,विघानसभेत अजितदादा काय बोलले तेवढच दाखवतो भाडखाउ , देवाभाउंनी सत्ताधाऱ्यांना फोडुन काढल अस बोलायला गांडीत दम लागतो, तु ऱ्भडव्या कोठ्यावर बसलायस मावशीच्या मांडीवर,बाजार उठणार लवकर.कटोरा येतोय बघ हातात,हरामखोर लाळचाटु चॅनल , तुमच्या तीरडीचा बांबु मोडला भडव्याहो
#  3                                                                                                                                                                                                                                    @ashish_jadhao @AUThackeray सरकार मधला बावळट संतरी आणि कुतरकार
#  4  ब्राह्मणवाद इतका वाईट, निच, आणि कपटी आहे की स्वतः जोतिबा फुले त्यांच्या मृत्यू पत्रात लिहतात... " शुद्रादी अतिशुद्रास दासनुदास मानणाऱ्या आर्यभट्ट ब्राह्मण जातीसह त्यांच्या अनुयायांची सुद्धा माझ्या शावावर व तत्संबंधी करीत असलेल्या विधिवर सावली सुद्धा पडू देऊ नये. " https://t.co/bQEWpfOBYw
#
#     label_yn
#  0         1
#  1         1
#  2         1
#  3         1
#  4         1  ,
#                  uid  \
#  0  l3cube_mr_test_0
#  1  l3cube_mr_test_1
#  2  l3cube_mr_test_2
#  3  l3cube_mr_test_3
#  4  l3cube_mr_test_4
#
#                                                                                                                                                                                               text  \
#  0                                                                        @GajuNaik20 @NitinRaut_INC अबे झाटु लालबहादूर यांना कोणी मारले इंदिरा गांधी यांना कशासाठी मारले माहिती घे गचपानतोंडाच्या
#  1                               @khadaksingh_ अंड नसलेल्या भक्तांना मोदी फायद्यात असणाऱ्या नवरत्न कंपन्या विकत असलेल्या दिसतनाही पण महाराष्ट्रात मात्र सतत भुकातात गजकर्ण झालेल्या कुत्र्या सारखे
#  2                                                                                                           @BhatkhalkarA अरे माठ्या त्यांच्याकडून काहीच शिकला नाहीस तु, भावपुर्ण श्रद्धांजली आबा
#  3  हे हिंदूंचे सरकार नव्हे तर लांड्यांचे सरकार ! या लांड्या सेनेने बाळासाहेबांना हटवून दाखवले 😠 @iYashwantJadhav #हिंदुत्व #शिवसेना #cmomaharashtra #uddhavthackeray #MVA https://t.co/prxg1v3cK3
#  4                                                                                                 @_prashantkadam कदम रडू नको तुझा मालक कोर्टात नेहमीच तोंडा वर पडतो कारण सगळेच बिनडोक भरले आहेत.
#
#     label_yn
#  0         1
#  1         1
#  2         1
#  3         1
#  4         1  )

# %%
from mahaNLP.preprocess import Preprocess

model2 = Preprocess()

def preprocess_text(text):
    text = model2.remove_url(text)
    text = ' '.join(model2.remove_stopwords(text))
    #text = model2.remove_nondevnagari(text) - inclusion of this step remove too many entries and leads to error
    return text

train_data['text'] = train_data['text'].apply(preprocess_text)
val_data['text'] = val_data['text'].apply(preprocess_text)
test_data['text'] = test_data['text'].apply(preprocess_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier

vectorizer = TfidfVectorizer(max_features=5000)
X_train = vectorizer.fit_transform(train_data['text'])
y_train = train_data['label_yn']

clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report

X_val = vectorizer.transform(val_data['text'])
y_val = val_data['label_yn']

X_test = vectorizer.transform(test_data['text'])
y_test = test_data['label_yn']

y_val_pred = clf.predict(X_val)
y_test_pred = clf.predict(X_test)

print("Validation Data Metrics:")
print("Accuracy:", accuracy_score(y_val, y_val_pred))
print(classification_report(y_val, y_val_pred))

print("\nTest Data Metrics:")
print("Accuracy:", accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Validation Data Metrics:
# Accuracy: 0.7661333333333333
#               precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77      1875
#            1       0.78      0.74      0.76      1875
#
#     accuracy                           0.77      3750
#    macro avg       0.77      0.77      0.77      3750
# weighted avg       0.77      0.77      0.77      3750
#
#
# Test Data Metrics:
# Accuracy: 0.7624
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77      1875
#            1       0.77      0.75      0.76      1875
#
#     accuracy                           0.76      3750
#    macro avg       0.76      0.76      0.76      3750
# weighted avg       0.76      0.76      0.76      3750

# %%
from sklearn.svm import SVC

clf_svm = SVC(kernel='linear', probability=True, random_state=42)
clf_svm.fit(X_train, y_train)

y_val_pred_svm = clf_svm.predict(X_val)
y_test_pred_svm = clf_svm.predict(X_test)

print("Validation Data Metrics (SVM):")
print("Accuracy:", accuracy_score(y_val, y_val_pred_svm))
print(classification_report(y_val, y_val_pred_svm))

print("\nTest Data Metrics (SVM):")
print("Accuracy:", accuracy_score(y_test, y_test_pred_svm))
print(classification_report(y_test, y_test_pred_svm))
# Out:
# Validation Data Metrics (SVM):
# Accuracy: 0.7904
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.79      1875
#            1       0.79      0.78      0.79      1875
#
#     accuracy                           0.79      3750
#    macro avg       0.79      0.79      0.79      3750
# weighted avg       0.79      0.79      0.79      3750
#
#
# Test Data Metrics (SVM):
# Accuracy: 0.7802666666666667
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.78      1875
#            1       0.78      0.79      0.78      1875
#
#     accuracy                           0.78      3750
#    macro avg       0.78      0.78      0.78      3750
# weighted avg       0.78      0.78      0.78      3750

# %%
from sklearn.linear_model import LogisticRegression

clf_lr = LogisticRegression(random_state=42)
clf_lr.fit(X_train, y_train)

y_val_pred_lr = clf_lr.predict(X_val)
y_test_pred_lr = clf_lr.predict(X_test)

print("Validation Data Metrics (Logistic Regression):")
print("Accuracy:", accuracy_score(y_val, y_val_pred_lr))
print(classification_report(y_val, y_val_pred_lr))

print("\nTest Data Metrics (Logistic Regression):")
print("Accuracy:", accuracy_score(y_test, y_test_pred_lr))
print(classification_report(y_test, y_test_pred_lr))
# Out:
# Validation Data Metrics (Logistic Regression):
# Accuracy: 0.7968
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80      1875
#            1       0.80      0.79      0.79      1875
#
#     accuracy                           0.80      3750
#    macro avg       0.80      0.80      0.80      3750
# weighted avg       0.80      0.80      0.80      3750
#
#
# Test Data Metrics (Logistic Regression):
# Accuracy: 0.7848
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79      1875
#            1       0.79      0.78      0.78      1875
#
#     accuracy                           0.78      3750
#    macro avg       0.78      0.78      0.78      3750
# weighted avg       0.78      0.78      0.78      3750

# %%
from sklearn.neighbors import KNeighborsClassifier

clf_knn = KNeighborsClassifier(n_neighbors=29) 
clf_knn.fit(X_train, y_train)

y_val_pred_knn = clf_knn.predict(X_val)
y_test_pred_knn = clf_knn.predict(X_test)

print("Validation Data Metrics (KNN):")
print("Accuracy:", accuracy_score(y_val, y_val_pred_knn))
print(classification_report(y_val, y_val_pred_knn))

print("\nTest Data Metrics (KNN):")
print("Accuracy:", accuracy_score(y_test, y_test_pred_knn))
print(classification_report(y_test, y_test_pred_knn))
# Out:
# Validation Data Metrics (KNN):
# Accuracy: 0.512
#               precision    recall  f1-score   support
#
#            0       0.87      0.03      0.05      1875
#            1       0.51      1.00      0.67      1875
#
#     accuracy                           0.51      3750
#    macro avg       0.69      0.51      0.36      3750
# weighted avg       0.69      0.51      0.36      3750
#
#
# Test Data Metrics (KNN):
# Accuracy: 0.5125333333333333
#               precision    recall  f1-score   support
#
#            0       0.89      0.03      0.06      1875
#            1       0.51      1.00      0.67      1875
#
#     accuracy                           0.51      3750
#    macro avg       0.70      0.51      0.36      3750
# weighted avg       0.70      0.51      0.36      3750
